# %%
import pandas as pd
import numpy as np
import requests

# %%
# Fetch the price of token0 (DeFi asset, against token1 in USDC)
uniswap_api_key = "2b45e1f034a61c2f41bf4bcd6731335a"
subgraph_id = "5zvR82QoaXYFyDEKLZ9t6v9adgnptxYpKpSbxtgVENFV"
url = f"https://gateway.thegraph.com/api/{uniswap_api_key}/subgraphs/id/{subgraph_id}"

pool_address = "0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8".lower()

query = """
query GetPoolPrice($id: ID!) {
  pool(id: $id) {
    id
    token0Price
    sqrtPrice
    liquidity
  }
}
"""

variables = {
    "id": pool_address
}

response = requests.post(url, json={"query": query, "variables": variables}).json()

# The price of executing an infintestimally small buy order (not accounting for slippage)
uniswap_price_small = response['data']['pool']['token0Price']
print(uniswap_price_small)
# Out:
# 3207.108379976377299522057980143507

# %%
# Fetch current coinbase order book ask data
product_id = 'ETH-USD'
url = f"https://api.exchange.coinbase.com/products/{product_id}/book?level=2"
out = requests.get(url).json()
bids = out['bids']
bids_df = pd.DataFrame(columns=['Price', 'Size (Units Coin)', 'Num Orders'], data=bids)
bids_df.head(20)
# Out:
#       Price Size (Units Coin)  Num Orders
# 0   3195.72        0.56568625           3
# 1   3195.71        0.09999999           1
# 2    3195.7        0.32153477           2
# 3    3195.6             0.147           2
# 4    3195.5             0.146           1
# 5   3195.45             0.001           1
# 6   3195.44        0.51491283           1
# 7   3195.41        0.71650056           1
# 8    3195.4             0.146           1
# 9   3195.33        0.74019633           1
# 10   3195.3             0.001           1
# 11  3195.29        0.01955615           1
# 12  3195.22            0.2834           1
# 13   3195.2                 1           1
# 14  3195.15             0.001           1
# 15  3195.09        0.13387878           2
# 16  3195.08        0.38446311           1
# 17  3195.07            0.4875           1
# 18  3195.04        2.40081636           1
# 19  3195.03        0.49764016           1

# %%
print(uniswap_price_small)
arbitrage = bids_df[bids_df['Price'] > uniswap_price_small]
arbitrage.head(50)
# Out:
#        Price Size (Units Coin)  Num Orders
# 7878  999.99        5.00620292           2
# 7879   999.9        0.00000047           1
# 7880  999.25         0.0124087           1
# 7881     999       93.04308743          11
# 7882  998.56         0.0370748           1
# 7883     998        5.12274549           2
# 7884  997.99        0.81008716           1
# 7885  997.87                 5           1
# 7886  997.46                 2           2
# 7887  997.02        0.04610575           1
# 7888     997        0.29909729           1
# 7889     996         0.9751506           1
# 7890  995.25        0.00499372           1
# 7891     995        0.08125431           1
# 7892  994.35                 1           1
# 7893     993                 7           1
# 7894  992.13        0.05009424           1
# 7895     992               0.5           1
# 7896  991.56              0.02           1
# 7897  990.11        0.39914756           1
# 7898     990               1.4           2
# 7899  989.01        0.30017012           1
# 7900  987.82        0.01006256           1
# 7901  987.31        0.01420379           1
# 7902     987        0.10070921           1
# 7903  986.51               1.5           1
# 7904  985.23              2.85           1
# 7905     985        0.00599999           1
# 7906  981.76         1.0124674           1
# 7907  981.09        0.03979815           1
# 7908     980        3.15552551           5
# 7909  979.03        1.01692491           1
# 7910   976.4        0.09337457           1
# 7911  975.46        0.02042146           1
# 7912     975        6.25487179           3
# 7913   974.1         0.0370748           1
# 7914  972.78        0.04725462           1
# 7915     971                 3           1
# 7916  969.69        0.07688024           1
# 7917     968        0.14289256           1
# 7918     966                 1           1
# 7919     965             1.075           1
# 7920  964.69        0.05183013           1
# 7921  963.18        0.01455963           1
# 7922  962.48         0.1247882           1
# 7923     962             0.051           1
# 7924     959        0.15547445           1
# 7925  957.01        0.04079954           1
# 7926     957                 1           1
# 7927     955        1.35597559           4
