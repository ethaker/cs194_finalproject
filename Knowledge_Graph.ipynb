# %%
import pandas as pd
import numpy as np
import requests

# %%
# 1. Fetch relevant blocks
# We wish to construct a time series with a bi-monthly granularity over a 2022-Present. To fetch data at each of these snapshots, we need
# the block ID of an ethereum block at each of these points, to give the global state of our desired liquidity pools at each of these snapshots

# Here, I will fetch block IDs with daily granularity (~1000 data points), and we can later choose which blocks to 
# include in our final time series


# Use Etherscan API

#

# %%
# 2. Liquidity pool A: BTC/USDC

# %%
# Generally in API call, you include the url (address of the server to query from), the specific query to be made, if working with
# a GraphQL query, and then format the response (requests.post().json())

## DO NOT MODIFY THIS ##
# API_KEY: 2b45e1f034a61c2f41bf4bcd6731335a
url = "https://gateway.thegraph.com/api/2b45e1f034a61c2f41bf4bcd6731335a/subgraphs/id/DiYPVdygkfjDWhbxGSqAQxwBKmfKnkWQojqeM2rkLb3G"

# Get the ID of the top 20 most liquid pools (most trade activity -> most likely to have price slippage)
query = """
{
  pools(first: 20) {
    id
    token0 { symbol }
    token1 { symbol }
    feeTier
  }
}
"""
response = requests.post(url, json={"query": query})
data = response.json()
data
# Out:
# {'data': {'pools': [{'feeTier': '991399',
#     'id': '0x0000b6dc3fa99f1e287a233c50edc6f1668e0ac6500c80d429f442a03449ca51',
#     'token0': {'symbol': 'ETH'},
#     'token1': {'symbol': 'IOST'}},
#    {'feeTier': '700000',
#     'id': '0x000305ccca383aaeee284804e6610b8ff9e42744ba5f3096f959bbbaed1d099c',
#     'token0': {'symbol': 'IWNon'},
#     'token1': {'symbol': 'USDC'}},
#    {'feeTier': '240000',
#     'id': '0x0003be2d3d4202dff5766085e6c00742a32ef88ebabed380ab1ec4fbb416604d',
#     'token0': {'symbol': 'ETH'},
#     'token1': {'symbol': 'XAR'}},
#    {'feeTier': '20000',
#     'id': '0x00065a5543d291419481d1e047554276f804b7c40ad90ad7ee8acd736e0de7e3',
#     'token0': {'symbol': 'ETH'},
#     'token1': {'symbol': 'SANCHAN'}},
#    {'feeTier': '100',
#     'id': '0x000713d84318dd4d1a6b9c47c7ebc842c56450bfe3c3babfc7ed5840a93c60f1',
#     'token0': {'symbol': 'USDT'},
#     'token1': {'symbol': 'USDT'}},
#    {'feeTier': '0',
#     'id': '0x0007bf35171b1c5daf926becf43b63eeca9976f8153fb70f79a7ed1093d467bc',
#     'token0': {'symbol': 'ETH'},
#     'token1': {'symbol': 'DOODSTR'}},
#    {'feeTier': '10000',
#     'id': '0x0009566976b1c86022e2d33dbeda238d5d7d5384cd94032c542c911ebf1836a4',
#     'token0': {'symbol': 'BIO'},
#     'token1': {'symbol': 'MITY'}},
#    {'feeTier': '3000',
#     'id': '0x000968a56080cf5d28be3007226a7285c121f887d032aa602d7d9f72af1658f0',
#     'token0': {'symbol': 'ETH'},
#     'token1': {'symbol': 'BOME'}},
#    {'feeTier': '100',
#     'id': '0x000a193942d54b2c53c150653b377006504bcd2892846e45495a9a0af1f45e3e',
#     'token0': {'symbol': 'UNI'},
#     'token1': {'symbol': 'USDT'}},
#    {'feeTier': '900000',
#     'id': '0x000a515b549af0f291b471fd95f52971f009099c05eb5dfabe35215113f89f5b',
#     'token0': {'symbol': 'sreUSD'},
#     'token1': {'symbol': 'reUSD'}},
#    {'feeTier': '3000',
#     'id': '0x000be4c726c3efa870db2b38ed8bde42c0ade20b9904c2fcd22a2d0c5d03843b',
#     'token0': {'symbol': 'EURC'},
#     'token1': {'symbol': 'EURT'}},
#    {'feeTier': '894000',
#     'id': '0x000e14e95d3535b377ffa446c9ab925c6fda973c5d470fb531862ff4a4b81e4f',
#     'token0': {'symbol': 'ETH'},
#     'token1': {'symbol': 'OPEN'}},
#    {'feeTier': '993000',
#     'id': '0x00145f1c543f7118eab01f9fb40f2901158d494f82c060b69898fcfd59234433',
#     'token0': {'symbol': 'ETH'},
#     'token1': {'symbol': 'ICE'}},
#    {'feeTier': '100000',
#     'id': '0x00189a32994c62502bcad657d2731d7f0b882134dc7d9f7812321565b6387453',
#     'token0': {'symbol': 'PORTAL'},
#     'token1': {'symbol': 'USDT'}},
#    {'feeTier': '900000',
#     'id': '0x001a7d213033c8ea1bf24bb8e6c9887bbcbf479ceca530efa0a9668f33389341',
#     'token0': {'symbol': 'ETH'},
#     'token1': {'symbol': 'TRIX'}},
#    {'feeTier': '100000',
#     'id': '0x001de7987cac4baebe4a7f37580c2db911bfcc78e55859b2e9d231425d3afaca',
#     'token0': {'symbol': 'ETH'},
#     'token1': {'symbol': 'ERC20'}},
#    {'feeTier': '800000',
#     'id': '0x00296290071d50a35b2bdfafc04b3c774a94dca05ea2d233665c14c10094ec0a',
#     'token0': {'symbol': 'USDT'},
#     'token1': {'symbol': 'INTCon'}},
#    {'feeTier': '850000',
#     'id': '0x002efe708828b0f228a8032064a7d0c8fa4907e04ddba043fa14744ef3fc1989',
#     'token0': {'symbol': 'eUSDf-1'},
#     'token1': {'symbol': 'USDf'}},
#    {'feeTier': '50000',
#     'id': '0x00335a44cfacbd184994ba956411debccaa5528af2506b6d731a3c38d04ffde4',
#     'token0': {'symbol': 'fUSDC'},
#     'token1': {'symbol': 'USDC'}},
#    {'feeTier': '10000',
#     'id': '0x003ad8691678e4d5b21ddc66b74172e61ddda305c02211a132fac7bfb9fcde16',
#     'token0': {'symbol': 'WBTC'},
#     'token1': {'symbol': 'USDe'}}]}}

# %%
# Now that we have the IDs of the top 10 pools, we wish to obtain

# %%
# 1. API Import: Import TVL of 10 chosen coins as array from Uniswap API
# 2. Construct graph: Directed graph, where edge from x to y gives amount of token y
# we need to trade for one token of x (edge values: y = k/x, x = k/y).
# 3. Visualize graph

# %%
# 1. API Call: We wish to get 
# API Documentation: https://docs.uniswap.org/contracts/v2/reference/API/entities

# %%
# Part II: Dashboard Construction
# Construct x instances of this graph, store instances in Neo4j database
